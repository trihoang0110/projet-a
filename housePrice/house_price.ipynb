# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Bengaluru_House_Data.csv')

# %%
df.head(15).style.set_table_styles(
[{'selector': 'th',
  'props': [('background', '#2CE1B0 '), 
            ('color', 'white'),
            ('font-size', 150),
            ('font-family', 'verdana')]},
 
 {'selector': 'td',
  'props': [('font-family', 'verdana')]},

 {'selector': 'tr:nth-of-type(odd)',
  'props': [('background', '#DCDCDC')]}, 
 
 {'selector': 'tr:nth-of-type(even)',
  'props': [('background', 'white')]},
 
 {'selector': 'tr:hover',
  'props': [('background-color', '#ED8B16 ')]}
 
]
).hide(axis='index')
# Out:
# <style type="text/css">
# #T_a9556 th {
#   background: #2CE1B0 ;
#   color: white;
#   font-size: 150;
#   font-family: verdana;
# }
# #T_a9556 td {
#   font-family: verdana;
# }
# #T_a9556 tr:nth-of-type(odd) {
#   background: #DCDCDC;
# }
# #T_a9556 tr:nth-of-type(even) {
#   background: white;
# }
# #T_a9556 tr:hover {
#   background-color: #ED8B16 ;
# }
# </style>
# <table id="T_a9556">
#   <thead>
#     <tr>
#       <th id="T_a9556_level0_col0" class="col_heading level0 col0" >area_type</th>
#       <th id="T_a9556_level0_col1" class="col_heading level0 col1" >availability</th>
#       <th id="T_a9556_level0_col2" class="col_heading level0 col2" >location</th>
#       <th id="T_a9556_level0_col3" class="col_heading level0 col3" >size</th>
#       <th id="T_a9556_level0_col4" class="col_heading level0 col4" >society</th>
#       <th id="T_a9556_level0_col5" class="col_heading level0 col5" >total_sqft</th>
#       <th id="T_a9556_level0_col6" class="col_heading level0 col6" >bath</th>
#       <th id="T_a9556_level0_col7" class="col_heading level0 col7" >balcony</th>
#       <th id="T_a9556_level0_col8" class="col_heading level0 col8" >price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_a9556_row0_col0" class="data row0 col0" >Super built-up  Area</td>
#       <td id="T_a9556_row0_col1" class="data row0 col1" >19-Dec</td>
#       <td id="T_a9556_row0_col2" class="data row0 col2" >Electronic City Phase II</td>
#       <td id="T_a9556_row0_col3" class="data row0 col3" >2 BHK</td>
#       <td id="T_a9556_row0_col4" class="data row0 col4" >Coomee </td>
#       <td id="T_a9556_row0_col5" class="data row0 col5" >1056</td>
#       <td id="T_a9556_row0_col6" class="data row0 col6" >2.000000</td>
#       <td id="T_a9556_row0_col7" class="data row0 col7" >1.000000</td>
#       <td id="T_a9556_row0_col8" class="data row0 col8" >39.070000</td>
#     </tr>
#     <tr>
#       <td id="T_a9556_row1_col0" class="data row1 col0" >Plot  Area</td>
#       <td id="T_a9556_row1_col1" class="data row1 col1" >Ready To Move</td>
#       <td id="T_a9556_row1_col2" class="data row1 col2" >Chikka Tirupathi</td>
#       <td id="T_a9556_row1_col3" class="data row1 col3" >4 Bedroom</td>
#       <td id="T_a9556_row1_col4" class="data row1 col4" >Theanmp</td>
#       <td id="T_a9556_row1_col5" class="data row1 col5" >2600</td>
#       <td id="T_a9556_row1_col6" class="data row1 col6" >5.000000</td>
#       <td id="T_a9556_row1_col7" class="data row1 col7" >3.000000</td>
#       <td id="T_a9556_row1_col8" class="data row1 col8" >120.000000</td>
#     </tr>
#     <tr>
#       <td id="T_a9556_row2_col0" class="data row2 col0" >Built-up  Area</td>
#       <td id="T_a9556_row2_col1" class="data row2 col1" >Ready To Move</td>
#       <td id="T_a9556_row2_col2" class="data row2 col2" >Uttarahalli</td>
#       <td id="T_a9556_row2_col3" class="data row2 col3" >3 BHK</td>
#       <td id="T_a9556_row2_col4" class="data row2 col4" >nan</td>
#       <td id="T_a9556_row2_col5" class="data row2 col5" >1440</td>
#       <td id="T_a9556_row2_col6" class="data row2 col6" >2.000000</td>
#       <td id="T_a9556_row2_col7" class="data row2 col7" >3.000000</td>
#       <td id="T_a9556_row2_col8" class="data row2 col8" >62.000000</td>
#     </tr>
#     <tr>
#       <td id="T_a9556_row3_col0" class="data row3 col0" >Super built-up  Area</td>
#       <td id="T_a9556_row3_col1" class="data row3 col1" >Ready To Move</td>
#       <td id="T_a9556_row3_col2" class="data row3 col2" >Lingadheeranahalli</td>
#       <td id="T_a9556_row3_col3" class="data row3 col3" >3 BHK</td>
#       <td id="T_a9556_row3_col4" class="data row3 col4" >Soiewre</td>
#       <td id="T_a9556_row3_col5" class="data row3 col5" >1521</td>
#       <td id="T_a9556_row3_col6" class="data row3 col6" >3.000000</td>
#       <td id="T_a9556_row3_col7" class="data row3 col7" >1.000000</td>
#       <td id="T_a9556_row3_col8" class="data row3 col8" >95.000000</td>
#     </tr>
#     <tr>
#       <td id="T_a9556_row4_col0" class="data row4 col0" >Super built-up  Area</td>
#       <td id="T_a9556_row4_col1" class="data row4 col1" >Ready To Move</td>
#       <td id="T_a9556_row4_col2" class="data row4 col2" >Kothanur</td>
#       <td id="T_a9556_row4_col3" class="data row4 col3" >2 BHK</td>
#       <td id="T_a9556_row4_col4" class="data row4 col4" >nan</td>
#       <td id="T_a9556_row4_col5" class="data row4 col5" >1200</td>
#       <td id="T_a9556_row4_col6" class="data row4 col6" >2.000000</td>
#       <td id="T_a9556_row4_col7" class="data row4 col7" >1.000000</td>
#       <td id="T_a9556_row4_col8" class="data row4 col8" >51.000000</td>
#     </tr>
#     <tr>
#       <td id="T_a9556_row5_col0" class="data row5 col0" >Super built-up  Area</td>
#       <td id="T_a9556_row5_col1" class="data row5 col1" >Ready To Move</td>
#       <td id="T_a9556_row5_col2" class="data row5 col2" >Whitefield</td>
#       <td id="T_a9556_row5_col3" class="data row5 col3" >2 BHK</td>
#       <td id="T_a9556_row5_col4" class="data row5 col4" >DuenaTa</td>
#       <td id="T_a9556_row5_col5" class="data row5 col5" >1170</td>
#       <td id="T_a9556_row5_col6" class="data row5 col6" >2.000000</td>
#       <td id="T_a9556_row5_col7" class="data row5 col7" >1.000000</td>
#       <td id="T_a9556_row5_col8" class="data row5 col8" >38.000000</td>
#     </tr>
#     <tr>
#       <td id="T_a9556_row6_col0" class="data row6 col0" >Super built-up  Area</td>
#       <td id="T_a9556_row6_col1" class="data row6 col1" >18-May</td>
#       <td id="T_a9556_row6_col2" class="data row6 col2" >Old Airport Road</td>
#       <td id="T_a9556_row6_col3" class="data row6 col3" >4 BHK</td>
#       <td id="T_a9556_row6_col4" class="data row6 col4" >Jaades </td>
#       <td id="T_a9556_row6_col5" class="data row6 col5" >2732</td>
#       <td id="T_a9556_row6_col6" class="data row6 col6" >4.000000</td>
#       <td id="T_a9556_row6_col7" class="data row6 col7" >nan</td>
#       <td id="T_a9556_row6_col8" class="data row6 col8" >204.000000</td>
#     </tr>
#     <tr>
#       <td id="T_a9556_row7_col0" class="data row7 col0" >Super built-up  Area</td>
#       <td id="T_a9556_row7_col1" class="data row7 col1" >Ready To Move</td>
#       <td id="T_a9556_row7_col2" class="data row7 col2" >Rajaji Nagar</td>
#       <td id="T_a9556_row7_col3" class="data row7 col3" >4 BHK</td>
#       <td id="T_a9556_row7_col4" class="data row7 col4" >Brway G</td>
#       <td id="T_a9556_row7_col5" class="data row7 col5" >3300</td>
#       <td id="T_a9556_row7_col6" class="data row7 col6" >4.000000</td>
#       <td id="T_a9556_row7_col7" class="data row7 col7" >nan</td>
#       <td id="T_a9556_row7_col8" class="data row7 col8" >600.000000</td>
#     </tr>
#     <tr>
#       <td id="T_a9556_row8_col0" class="data row8 col0" >Super built-up  Area</td>
#       <td id="T_a9556_row8_col1" class="data row8 col1" >Ready To Move</td>
#       <td id="T_a9556_row8_col2" class="data row8 col2" >Marathahalli</td>
#       <td id="T_a9556_row8_col3" class="data row8 col3" >3 BHK</td>
#       <td id="T_a9556_row8_col4" class="data row8 col4" >nan</td>
#       <td id="T_a9556_row8_col5" class="data row8 col5" >1310</td>
#       <td id="T_a9556_row8_col6" class="data row8 col6" >3.000000</td>
#       <td id="T_a9556_row8_col7" class="data row8 col7" >1.000000</td>
#       <td id="T_a9556_row8_col8" class="data row8 col8" >63.250000</td>
#     </tr>
#     <tr>
#       <td id="T_a9556_row9_col0" class="data row9 col0" >Plot  Area</td>
#       <td id="T_a9556_row9_col1" class="data row9 col1" >Ready To Move</td>
#       <td id="T_a9556_row9_col2" class="data row9 col2" >Gandhi Bazar</td>
#       <td id="T_a9556_row9_col3" class="data row9 col3" >6 Bedroom</td>
#       <td id="T_a9556_row9_col4" class="data row9 col4" >nan</td>
#       <td id="T_a9556_row9_col5" class="data row9 col5" >1020</td>
#       <td id="T_a9556_row9_col6" class="data row9 col6" >6.000000</td>
#       <td id="T_a9556_row9_col7" class="data row9 col7" >nan</td>
#       <td id="T_a9556_row9_col8" class="data row9 col8" >370.000000</td>
#     </tr>
#     <tr>
#       <td id="T_a9556_row10_col0" class="data row10 col0" >Super built-up  Area</td>
#       <td id="T_a9556_row10_col1" class="data row10 col1" >18-Feb</td>
#       <td id="T_a9

# %%
df.shape
# Out:
# (13320, 9)

# %%
df.dtypes
# Out:
# area_type        object
# availability     object
# location         object
# size             object
# society          object
# total_sqft       object
# bath            float64
# balcony         float64
# price           float64
# dtype: object

# %%
# df['total_sqft'] = df['total_sqft'].astype(int)
# df['bath'] = df['bath'].astype(int)
# df['balcony'] = df['balcony'].astype(int)

# %%
# There is null, Nan value in the dataset.
df.isnull().any(axis=0)
# Out:
# area_type       False
# availability    False
# location         True
# size             True
# society          True
# total_sqft      False
# bath             True
# balcony          True
# price           False
# dtype: bool

# %%
def check_null(col_name):
    return len(df[df[col_name].isnull()])

# %%
for col in df.columns:
    print(f'there are {check_null(col)} rows with missing values for {col} col')
# Out:
# there are 0 rows with missing values for area_type col
# there are 0 rows with missing values for availability col
# there are 1 rows with missing values for location col
# there are 16 rows with missing values for size col
# there are 5502 rows with missing values for society col
# there are 0 rows with missing values for total_sqft col
# there are 73 rows with missing values for bath col
# there are 609 rows with missing values for balcony col
# there are 0 rows with missing values for price col

# %%
# i will not use these cols: avai;ability, society
df.drop(['availability', 'society'], axis='columns', inplace=True)

# %%
# There are still nan values in certain cols. In this project, i wlll simply drop the rows with nan. However,
# certain imputing techniques can be applied instead
df.dropna(inplace=True)
df.isnull().sum()
# Out:
# area_type     0
# location      0
# size          0
# total_sqft    0
# bath          0
# balcony       0
# price         0
# dtype: int64

# %%
df['size'].unique()
# Out:
# array(['2 BHK', '4 Bedroom', '3 BHK', '3 Bedroom', '1 BHK', '1 RK',
#        '4 BHK', '1 Bedroom', '2 Bedroom', '6 Bedroom', '8 Bedroom',
#        '7 Bedroom', '5 BHK', '7 BHK', '6 BHK', '5 Bedroom', '11 BHK',
#        '9 BHK', '9 Bedroom', '27 BHK', '11 Bedroom', '43 Bedroom',
#        '14 BHK', '8 BHK', '12 Bedroom', '10 Bedroom', '13 BHK'],
#       dtype=object)

# %%
df['size'] = df['size'].apply(lambda x: int(x.split()[0]))

# %%
# for this project, i will only focus on the apartmen with less than or equal to 5 bedrooms and 5 bath
df = df[(df['size']<=5) & (df['bath']<=5)]

# %%
df.sort_values(by=['price', 'size'], ascending=False).head(10)
# Out:
#                   area_type             location  size total_sqft  bath  \
# 11080  Super built-up  Area          Ashok Nagar     4       8321   5.0
# 3180   Super built-up  Area      Shanthala Nagar     5       8321   5.0
# 10304            Plot  Area  5th Block Jayanagar     4      10624   4.0
# 6421             Plot  Area         Bommenahalli     4       2940   3.0
# 7315             Plot  Area               Yemlur     4      11000   5.0
# 8546             Plot  Area       Dollars Colony     3       7800   3.0
# 8682             Plot  Area               Yemlur     4       8400   5.0
# 8165   Super built-up  Area        Church Street     4      11000   4.0
# 7082   Super built-up  Area               Ulsoor     4       7200   5.0
# 9439   Super built-up  Area      Sadashiva Nagar     5       7500   5.0
#
#        balcony   price
# 11080      2.0  2912.0
# 3180       3.0  2700.0
# 10304      2.0  2340.0
# 6421       2.0  2250.0
# 7315       3.0  2000.0
# 8546       2.0  2000.0
# 8682       2.0  1675.0
# 8165       1.0  1600.0
# 7082       2.0  1584.0
# 9439       2.0  1500.0

# %%
def is_float(num):
    try:
        float(num)
    except:
        return False
    return True

# %%
df
# Out:
#                   area_type                  location  size total_sqft  bath  \
# 0      Super built-up  Area  Electronic City Phase II     2       1056   2.0
# 1                Plot  Area          Chikka Tirupathi     4       2600   5.0
# 2            Built-up  Area               Uttarahalli     3       1440   2.0
# 3      Super built-up  Area        Lingadheeranahalli     3       1521   3.0
# 4      Super built-up  Area                  Kothanur     2       1200   2.0
# ...                     ...                       ...   ...        ...   ...
# 13314  Super built-up  Area         Green Glen Layout     3       1715   3.0
# 13315        Built-up  Area                Whitefield     5       3453   4.0
# 13317        Built-up  Area     Raja Rajeshwari Nagar     2       1141   2.0
# 13318  Super built-up  Area           Padmanabhanagar     4       4689   4.0
# 13319  Super built-up  Area              Doddathoguru     1        550   1.0
#
#        balcony   price
# 0          1.0   39.07
# 1          3.0  120.00
# 2          3.0   62.00
# 3          1.0   95.00
# 4          1.0   51.00
# ...        ...     ...
# 13314      3.0  112.00
# 13315      0.0  231.00
# 13317      1.0   60.00
# 13318      1.0  488.00
# 13319      1.0   17.00
#
# [12201 rows x 7 columns]

# %%
df[~df['total_sqft'].apply(is_float)].head(10)
# Out:
#                 area_type               location  size      total_sqft  bath  \
# 30   Super built-up  Area              Yelahanka     4     2100 - 2850   4.0
# 122  Super built-up  Area                 Hebbal     4     3067 - 8156   4.0
# 137  Super built-up  Area     8th Phase JP Nagar     2     1042 - 1105   2.0
# 165  Super built-up  Area               Sarjapur     2     1145 - 1340   2.0
# 188  Super built-up  Area               KR Puram     2     1015 - 1540   2.0
# 410  Super built-up  Area                Kengeri     1  34.46Sq. Meter   1.0
# 549  Super built-up  Area            Hennur Road     2     1195 - 1440   2.0
# 661  Super built-up  Area              Yelahanka     2     1120 - 1145   2.0
# 672        Built-up  Area           Bettahalsoor     4     3090 - 5002   4.0
# 772  Super built-up  Area  Banashankari Stage VI     2     1160 - 1195   2.0
#
#      balcony    price
# 30       0.0  186.000
# 122      0.0  477.000
# 137      0.0   54.005
# 165      0.0   43.490
# 188      0.0   56.800
# 410      0.0   18.500
# 549      0.0   63.770
# 661      0.0   48.130
# 672      0.0  445.000
# 772      0.0   59.935

# %%
measure_units = {'Sq. Meter':10.7639, 'Acres':43560, 'Sq. Yards':9, 'Guntha':1089 , 'Grounds':2400}
def convert_to_num(x):
    tokens = x.strip().split('-')
    if len(tokens) == 2:
        return (float(tokens[0])+float(tokens[1]))/2   
    try:
        return float(tokens[0])
    except:
        for unit, num in measure_units.items():
            if unit in tokens[0]:
                return float(tokens[0][:-len(unit)])*num
            break

# %%
df['total_sqft'] = df['total_sqft'].apply(convert_to_num)

# %%
# Sq. Meter, Acres, Sq. Yards, Guntha, Grounds
df = df.reset_index(drop=True)

# %%
df[df['total_sqft']<=10000].sort_values(by=['price'], ascending=False).head(10)
# Out:
#                   area_type         location  size  total_sqft  bath  balcony  \
# 10140  Super built-up  Area      Ashok Nagar     4      8321.0   5.0      2.0
# 2903   Super built-up  Area  Shanthala Nagar     5      8321.0   5.0      3.0
# 5855             Plot  Area     Bommenahalli     4      2940.0   3.0      2.0
# 7787             Plot  Area   Dollars Colony     3      7800.0   3.0      2.0
# 7913             Plot  Area           Yemlur     4      8400.0   5.0      2.0
# 6459   Super built-up  Area           Ulsoor     4      7200.0   5.0      2.0
# 2888             Plot  Area     Malleshwaram     4      5500.0   5.0      1.0
# 8618   Super built-up  Area  Sadashiva Nagar     5      7500.0   5.0      2.0
# 8381   Super built-up  Area     Malleshwaram     4      6500.0   4.0      3.0
# 8766   Super built-up  Area     Rajaji Nagar     4      6500.0   5.0      2.0
#
#         price
# 10140  2912.0
# 2903   2700.0
# 5855   2250.0
# 7787   2000.0
# 7913   1675.0
# 6459   1584.0
# 2888   1500.0
# 8618   1500.0
# 8381   1400.0
# 8766   1400.0

# %%
# We will consider only apartmant with total sqft less than or equal to 5000
df1 = df[df['total_sqft']<=5000]

# %%
# df1.location = df1.location.apply(lambda x: x.strip())

# %%
# location_count = df1.groupby('location')['location'].agg('count').sort_values(ascending=False)
# location_count

# %%
# location_less_than_10 = location_count[location_count<10]

# %%
# print(f"number of unique locations {len(df1['location'].unique())}")

# %%
# df1['location_label'] = df1['location'].apply(lambda x: 'other' if x in location_less_than_10 else x)

# %%
df2 = df1.copy()

# %%
# the average bedroom size is 132 or 120
# the average bathroom size 40
del df1
df2['bed_bath'] = df2['size'] *132 + df2['bath'] *40

# %%
df2 = df2[df2['total_sqft']>df2['bed_bath']]

# %%
df3 = df2.copy()

# %%
# 1 lakh = 100000 rupees
del df2
df3['price_per_sqft'] = round((df3['price']*100000)/df3['total_sqft'],3)
df3
# Out:
#                   area_type                  location  size  total_sqft  bath  \
# 0      Super built-up  Area  Electronic City Phase II     2      1056.0   2.0
# 1                Plot  Area          Chikka Tirupathi     4      2600.0   5.0
# 2            Built-up  Area               Uttarahalli     3      1440.0   2.0
# 3      Super built-up  Area        Lingadheeranahalli     3      1521.0   3.0
# 4      Super built-up  Area                  Kothanur     2      1200.0   2.0
# ...                     ...                       ...   ...         ...   ...
# 12196  Super built-up  Area         Green Glen Layout     3      1715.0   3.0
# 12197        Built-up  Area                Whitefield     5      3453.0   4.0
# 12198        Built-up  Area     Raja Rajeshwari Nagar     2      1141.0   2.0
# 12199  Super built-up  Area           Padmanabhanagar     4      4689.0   4.0
# 12200  Super built-up  Area              Doddathoguru     1       550.0   1.0
#
#        balcony   price  bed_bath  price_per_sqft
# 0          1.0   39.07     344.0        3699.811
# 1          3.0  120.00     728.0        4615.385
# 2          3.0   62.00     476.0        4305.556
# 3          1.0   95.00     516.0        6245.891
# 4          1.0   51.00     344.0        4250.000
# ...        ...     ...       ...             ...
# 12196      3.0  112.00     516.0        6530.612
# 12197      0.0  231.00     820.0        6689.835
# 12198      1.0   60.00     344.0        5258.545
# 12199      1.0  488.00     688.0       10407.336
# 12200      1.0   17.00     172.0        3090.909
#
# [12028 rows x 9 columns]

# %%
df3.describe()['price_per_sqft']
# Out:
# count     12028.000000
# mean       6255.312070
# std        3966.406004
# min         500.000000
# 25%        4200.678750
# 50%        5277.913500
# 75%        6896.552000
# max      176470.588000
# Name: price_per_sqft, dtype: float64

# %%
# interquartile = df3.describe()['price_per_sqft']['75%'] -  df3.describe()['price_per_sqft']['25%']
# lower_bound = df3.describe()['price_per_sqft']['25%'] - 1.5*interquartile
# upper_bound = df3.describe()['price_per_sqft']['75%'] + 1.5*interquartile

# %%
lower_bound = df3.describe()['price_per_sqft']['mean'] - 1*df3.describe()['price_per_sqft']['std']
upper_bound = df3.describe()['price_per_sqft']['mean'] + 1*df3.describe()['price_per_sqft']['std']

# %%
df3 = df3[(df3['price_per_sqft']>=lower_bound) & (df3['price_per_sqft']<=upper_bound)]

# %%
df3.sort_values(by=['price_per_sqft'], ascending=False)
# Out:
#                   area_type                location  size  total_sqft  bath  \
# 489    Super built-up  Area                  Hebbal     3      2400.0   4.0
# 3671   Super built-up  Area           Wilson Garden     1       735.0   1.0
# 11464  Super built-up  Area       Nagawara Junction     1       500.0   1.0
# 3903             Plot  Area              Whitefield     4      3000.0   4.0
# 11361  Super built-up  Area             Basavangudi     4      2453.0   3.0
# ...                     ...                     ...   ...         ...   ...
# 1717   Super built-up  Area  Kengeri Satellite Town     2      1072.0   2.0
# 8088   Super built-up  Area            Doddathoguru     2      1140.0   2.0
# 5942   Super built-up  Area                 Hoskote     3      1250.0   3.0
# 2200   Super built-up  Area             Kammasandra     2      1018.0   2.0
# 2479   Super built-up  Area              Chandapura     1       590.0   1.0
#
#        balcony   price  bed_bath  price_per_sqft
# 489        1.0  245.00     556.0       10208.333
# 3671       1.0   75.00     172.0       10204.082
# 11464      2.0   51.00     172.0       10200.000
# 3903       3.0  306.00     688.0       10200.000
# 11361      2.0  250.00     648.0       10191.602
# ...        ...     ...       ...             ...
# 1717       1.0   25.00     344.0        2332.090
# 8088       2.0   26.49     344.0        2323.684
# 5942       2.0   29.00     516.0        2320.000
# 2200       0.0   23.45     344.0        2303.536
# 2479       0.0   13.57     172.0        2300.000
#
# [10852 rows x 9 columns]

# %%
print(f"number of unique locations {len(df3['location'].unique())}")
# Out:
# number of unique locations 1067

# %%
# df3.location = df3.location.apply(lambda x: x.strip())

# %%
# location_count = df3.groupby('location')['location'].agg('count').sort_values(ascending=False)

# %%
# location_less_than_10 =  location_count[location_count<10]

# %%
# df3['location'] = df3['location'].apply(lambda x: 'other' if x in location_less_than_10 else x)

# %%
df3['bath'] = df['bath'].astype(int)
df3['balcony'] = df['balcony'].astype(int)
# Out:
# C:\Users\ultra\AppData\Local\Temp\ipykernel_11716\3967610630.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['bath'] = df['bath'].astype(int)
# C:\Users\ultra\AppData\Local\Temp\ipykernel_11716\3967610630.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['balcony'] = df['balcony'].astype(int)

# %%
loc_ranking = df3.groupby('location').mean().sort_values(by='price_per_sqft', ascending=False).index

# %%
loc_ranking
# Out:
# Index(['Dairy Circle', '7th Block Jayanagar', 'Vivek Nagar', 'Kavika Layout',
#        'Nandi Durga Road', 'Okalipura', 'cooketown', 'akshaya nagar t c palya',
#        'Domlur Layout', 'Guni Agrahara',
#        ...
#        'Jeevanhalli', 'BAGUR ROAD', 'Vidhyanagar Cross', 'Huskur',
#        'Tunganagara', 'Madanayakahalli', 'Phase 1 Kammasandra', 'Handenahalli',
#        'BDS Layout', 'BAGUR'],
#       dtype='object', name='location', length=1067)

# %%
top1 = loc_ranking[:234]
top2 = loc_ranking[234:468]
top3 = loc_ranking[468:702]
top4 = loc_ranking[702:936]
top5 = loc_ranking[936:]

# %%
# top1 = loc_ranking[:100]
# top2 = loc_ranking[100:200]
# top3 = loc_ranking[200:300]
# top4 = loc_ranking[300:400]
# top5 = loc_ranking[500:600]
# top6 = loc_ranking[600:700]
# top7 = loc_ranking[700:800]
# top8 = loc_ranking[800:900]
# top9 = loc_ranking[1000:1100]
# top10 = loc_ranking[1000:]

# %%
def rank(x):
    if x in top1:
        return 'top1'
    if x in top2:
        return 'top2'
    if x in top3:
        return 'top3'
    if x in top4:
        return 'top4'
    if x in top5:
        return 'top5'

# %%
# def rank(x):
#     if x in top1:
#         return 'top1'
#     if x in top2:
#         return 'top2'
#     if x in top3:
#         return 'top3'
#     if x in top4:
#         return 'top4'
#     if x in top5:
#         return 'top5'
#     if x in top6:
#         return 'top6'
#     if x in top7:
#         return 'top7'
#     if x in top8:
#         return 'top8'
#     if x in top9:
#         return 'top9'
#     if x in top10:
#         return 'top10'

# %%
df4 = df3.copy()
df4['location'] = df3['location'].apply(rank)

# %%
df4 = df4.drop(['bed_bath', 'price_per_sqft'], axis='columns')
dummies1 = pd.get_dummies(df4.location, drop_first=False)
dummies2 = pd.get_dummies(df4.area_type, drop_first=False)
df5 = pd.concat([df4, dummies1, dummies2], axis='columns')

# %%
ranking = []
for loc in loc_ranking:
    ranking.append(rank(loc))

# %%
loc_dimension = pd.DataFrame({'location': loc_ranking, 'ranking': ranking})

# %%
loc_dimension
# Out:
#                  location ranking
# 0            Dairy Circle    top1
# 1     7th Block Jayanagar    top1
# 2             Vivek Nagar    top1
# 3           Kavika Layout    top1
# 4        Nandi Durga Road    top1
# ...                   ...     ...
# 1062      Madanayakahalli    top5
# 1063  Phase 1 Kammasandra    top5
# 1064         Handenahalli    top5
# 1065           BDS Layout    top5
# 1066                BAGUR    top5
#
# [1067 rows x 2 columns]

# %%
avg_top5 = df3[df3['location']=='top5']['price'].mean()
avg_top4 = df3[df3['location']=='top4']['price'].mean()
avg_top3 = df3[df3['location']=='top3']['price'].mean()
avg_top2 = df3[df3['location']=='top2']['price'].mean()
avg_top1 = df3[df3['location']=='top1']['price'].mean()

# %%
g = sns.FacetGrid(df4, hue='area_type', col='location', col_wrap=3, height=4, aspect=1.5,
                  col_order=['top5', 'top4', 'top3', 'top2', 'top1'])
g = g.map(plt.scatter, "total_sqft", "price", edgecolor="w")
ax1, ax2, ax3, ax4, ax5 = g.axes

ax1.axhline(avg_top5, ls='--')
ax2.axhline(avg_top4, ls='--')
ax3.axhline(avg_top3, ls='--')
ax4.axhline(avg_top2, ls='--')
ax5.axhline(avg_top1, ls='--')
plt.show()

# %%
# df3[df3['location_label']=='other'].sort_values(by=['price_per_sqft', 'location'], ascending=False).head(30)

# %%
# interquartile = df2.describe()['price_per_sqft']['75%'] - df2.describe()['price_per_sqft']['25%']

# %%
# dummies = pd.get_dummies(df3.location)

# %%
# df4 = pd.concat([df3, dummies.drop('other', axis='columns')], axis='columns')

# %%
X = df5.drop(['area_type', 'location', 'price', 'balcony'], axis='columns')
X.head()
# Out:
#    size  total_sqft  bath  top1  top2  top3  top4  top5  Built-up  Area  \
# 0     2      1056.0     2     0     0     0     0     1               0
# 1     4      2600.0     5     0     0     0     1     0               0
# 2     3      1440.0     2     0     0     0     1     0               1
# 3     3      1521.0     3     0     1     0     0     0               0
# 4     2      1200.0     2     0     0     1     0     0               0
#
#    Carpet  Area  Plot  Area  Super built-up  Area
# 0             0           0                     1
# 1             0           1                     0
# 2             0           0                     0
# 3             0           0                     1
# 4             0           0                     1

# %%
y = df5.price

# %%
from sklearn.model_selection import ShuffleSplit, cross_val_score
from sklearn.linear_model import LinearRegression

# %%
cv = ShuffleSplit(n_splits=5, test_size=0.2, random_state=0)
cross_val_score(LinearRegression(), X, y, cv=cv)
# sum(cross_val_score(LinearRegression(), X, y, cv=cv))/5
# Out:
# array([0.83757424, 0.8133276 , 0.81649918, 0.81767825, 0.81745909])

# %%
sum(cross_val_score(LinearRegression(), X, y, cv=cv))/5
# Out:
# 0.820507670392459

# %%
lr = LinearRegression()
lr.fit(X, y)
preds = lr.predict(X)

# %%
errors = list(y - preds)

# %%
y.describe()
# Out:
# count    10852.000000
# mean        77.658879
# std         49.996226
# min          8.000000
# 25%         46.407500
# 50%         64.310000
# 75%         90.532500
# max        465.000000
# Name: price, dtype: float64

# %%
data = {'preds': list(preds), 'errors': errors, 'total_sqft':list(X.total_sqft)}
res = pd.DataFrame(data)
res
# Out:
#             preds     errors  total_sqft
# 0       35.368185   3.701815      1056.0
# 1      167.765492 -47.765492      2600.0
# 2       63.618691  -1.618691      1440.0
# 3       92.589325   2.410675      1521.0
# 4       61.079462 -10.079462      1200.0
# ...           ...        ...         ...
# 10847   57.634735  -0.634735      1345.0
# 10848  106.248123   5.751877      1715.0
# 10849  212.597645  18.402355      3453.0
# 10850   47.747827  12.252173      1141.0
# 10851    0.353519  16.646481       550.0
#
# [10852 rows x 3 columns]

# %%
g = sns.FacetGrid(res, height=6, aspect=1.5)
g = g.map(plt.scatter, "preds", "errors", edgecolor="w")
ax1 = g.ax

ax1.axhline(0, ls='--')
plt.show()

# %% [markdown]
# ##### We can certainly see that the assumption of linear regression is not ok because the variance of error increases as total sqft rises
# #### As a result, we'll develop other models, but still use linear regression for dashboard in powerbi

# %%
coef = lr.coef_

# %%
lr.coef_
# Out:
# array([ -5.1805819 ,   0.07040617,   4.56972456,  28.44338744,
#          6.04086413,  -3.47947462, -11.95251466, -19.05226228,
#         -5.46917474,   1.75584589,   8.47787271,  -4.76454386])

# %%
lr.intercept_
# Out:
# -13.94221367790584

# %%
components = pd.DataFrame({'components': X.columns, 'values': coef})

# %%
components = components.append({'components': 'intercept', 'values': lr.intercept_}, ignore_index=True)
# Out:
# C:\Users\ultra\AppData\Local\Temp\ipykernel_11716\1800476339.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append({'components': 'intercept', 'values': lr.intercept_}, ignore_index=True)

# %%
df3.to_csv('house_price.csv', index=False)
loc_dimension.to_csv('loc_dimension.csv', index=False)
components.to_csv('components.csv', index=False)
